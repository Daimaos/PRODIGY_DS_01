# %% [markdown]
# # 📊 Prodigy InfoTech Data Science Internship
#
# ## 📝 Task-01: Visualizing Data Distribution with Bar Chart / Histogram
#
# **Intern:** Hashir Muhammed
# **Track:** Data Science
# **Task Code:** PRODIGY_DS_01
#
# ---
#
# ## 🎯 Task Objective:
#
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of populations in different countries.
#
# **Dataset Source:** [World Bank Population Data](https://data.worldbank.org/indicator/SP.POP.TOTL)
#
# ---
#
# ## 🛠️ Tools Used:
# - Python
# - Pandas
# - Matplotlib
# - Seaborn

# %% [markdown]
# ## 📥 Step 1: Import Required Libraries & DataSet

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("population.csv")

# %%
data.head(266)
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
#List of contries for the graph.
countries_to_plot = ['United States', 'Canada', 'Brazil', 'Japan', 'Germany', 'France']

#Filtering the data frame
filtered_data = data[data['Country Name'].isin(countries_to_plot)]

#Creating the bar chart
plt.bar (filtered_data['Country Name'], filtered_data['2022'])
plt.xlabel ('Country Name')
plt.ylabel ('Population in 2022')
plt.title('Population of selected countries in 2022')
plt.xticks(rotation=45, ha='right') #Rotating the x-axis labels for readability
plt.show()

# %% [markdown]
# ## 📊 Step 4: Create a Histogram to Visualize Distribution of City Populations

# %%
import numpy as np

# Generate random sample population data for cities
city_populations = np.random.normal(500000, 200000, 1000)

# Plotting the Histogram
plt.figure(figsize=(10,6))
plt.hist(city_populations, bins=30, color='coral', edgecolor='black')

# Add labels and title
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title('Distribution of City Populations (Sample Data)', fontsize=16)
plt.show()
